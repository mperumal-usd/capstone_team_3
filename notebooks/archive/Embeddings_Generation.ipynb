# %% [markdown]
# <a href="https://colab.research.google.com/github/mperumal-usd/capstone_team_3/blob/main/Embeddings_Generation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/mperumal-usd/capstone_team_3
# Out:
# Cloning into 'capstone_team_3'...
# remote: Enumerating objects: 4773, done.
# remote: Counting objects: 100% (43/43), done.
# remote: Compressing objects: 100% (39/39), done.
# remote: Total 4773 (delta 8), reused 29 (delta 4), pack-reused 4730 (from 3)
# Receiving objects: 100% (4773/4773), 50.42 MiB | 20.67 MiB/s, done.
# Resolving deltas: 100% (40/40), done.
# Updating files: 100% (6339/6339), done.
